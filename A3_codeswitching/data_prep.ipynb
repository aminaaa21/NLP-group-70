# %%
import pandas as pd

# %%
# example of data
data = {
    "id": "",
    "text": "",
    "pair": "english-",
    "languages": ["english", ""],
    "created_by": "" 
},

# %%
dataset = [
    {
        "id": 1,
        "text": "yaar mujhe literally kuch bhi nahi samajh aaya in that lecture",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 2,
        "text": "ik snap het gewoon niet man, deze assignment maakt absoluut geen sense",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 3,
        "text": "het is echt too much, I don't think we'll finish this op tijd",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 4,
        "text": "gezellig was het last night, we should definitely do this nog een keertje",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 5,
        "text": "ik heb no clue what we should eat, zullen we gewoon iets orderen",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 6,
        "text": "man het weer is so depressing, ik wil niet naar de library",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 7,
        "text": "ik ben zo exhausted, I stayed up tot like drie uur vannacht",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 8,
        "text": "calm down joh, je maakt het veel te complicated",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 9,
        "text": "I'm going to do boodschappen, wat voor ingredients heb je nodig voor dinner?",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 10,
        "text": "ik ben echt stressed voor mijn exam, maar ik moet mijn drivers-license halen.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 11,
        "text": "ik heb al voor a lot of part-time jobs applied, maar ik wordt steeds niet gehired.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 12,
        "text": "de grading van deze assignment vind ik eigenlijk really unfair.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 13,
        "text": "ik koop mijn birthday gifts altijd bij de bookstore.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 14,
        "text": "Tijdens mijn internship had ik een co-worker die echt veel yapte",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 15,
        "text": "Bhai I'm so stressed, mere itne saare deadlines hain this week",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 16,
        "text": "Unhone mujhe ghost kar diya, I can't believe it",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 17,
        "text": "Tu bas relax kar, it'll be fine",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 18,
        "text": "us ne mujhe last minute pe cancel kar diya, so rude",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 19,
        "text": "uye outfit is so cute, kahan se liya?",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 20,
        "text": "wo banda itna fake hai, I don't trust him at all",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },  

    {
        "id": 21,
        "text": "Itna overthink mat karo, it'll all work out",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 22,
        "text": "mein ne groceries order kar di hain, they'll arrive in an hour",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },
    
    
    {
        "id": 23,
        "text": "mujhe na actually ye show bohot pasand hai, it's so good",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 24,
        "text": "mujhe samajh nahi aata why people always leave their dishes in the sink, itna difficult hai kya clean karna?",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 25,
        "text": "main supermarket gayi thi just milk lene ke liye and I ended up spending like 30 euros, har baar aisa hota hai",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 26,
        "text": "aaj gym jaana tha but I kept snoozing my alarm, ab mujhe guilty feel ho raha hai poora din",
        "pair": "english-hindi",
        "languages": ["english", "hindi"],
        "created_by": "Amina" 
    },

    {
        "id": 27,
        "text": "naan romba tired, but I still have to finish my work tonight",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 28,
        "text": "seri let's order food, enakku cooking panna mood illa",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    { 
        "id": 29,
        "text": "enna da, this assignment is so difficult, enakku puriyala",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 30,
        "text": "I have so many deadlines this week, enakku stressa irrukuru",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 31,
        "text": "naan oru movie paarke plan panninen, but I don't think it's gonna happen this week",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 32,
        "text": "naan sick a iruken, I think I caught a cold in Berlin",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 33,
        "text": "naan holidaykku Berlin poi wanden, but I didn't get to do anything fun there",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 34,
        "text": "naan oru Kingsday party attend panninen, it was so much fun, and aduthe naal, I had to get up early work poga",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 35,
        "text": "I just came back from my ammas place, I just had the best food ever, iddiayappam and meen curry, such a good combination",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 36,
        "text": "naan saravana bhavan ikku saapadu saapide ponnen, their vada idli set is pretty popular",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 37,
        "text": "summer holidaykku naan India poga plan pannuren, lets see if it is gonna happen",
        "pair": "english-tamil",        
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 38,
        "text": "Naan oru new series pakuren, called 'Boyfriend on demand'. I am totally addicted, enna oru story.",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },
    
    { 
        "id": 39,
        "text": "eppada indha padippu mudiyum indhu irukkuru, I hope soon",
        "pair": "english-tamil",
        "languages": ["english", "tamil"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 40,
        "text": "Can you help me writing this letter, ich weiß nicht how to start it",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"

    }, 

    {
        "id": 41,
        "text": "I am going to book an Uber, kannst du mir sagen wo du bist?",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    }, 

    {
        "id": 42,
        "text": "Ich habe kaum geschalfen, I feel so sick.",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 43,
        "text": "Mein WiFi funktioniert nicht, I can't do anything",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"

    },

    {
        "id": 44,
        "text": "Ich war heute im Patch Work and wanted to buy a bicycle, but I didn't have enough money with me",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    },

    {   
        "id": 45,
        "text": "I heard about the Tulpensaison in the Netherlands, it must be such a nice view",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"

    }, 

    {
        "id": 46,
        "text": "Meine Mama musste ihren Pass erneuern, we had to go to the embassy together, it was such a hassle to get to Berlin.",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    }, 
    
    {   
        "id": 47,
        "text": "Bruder Jakob, Bruder Jakob, schläfst du noch, are you still sleeping, hörst du nicht die Glocken, can't you hear the bells, ding, dong dang?",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 48,
        "text": "Twinkle, twinkle, kleiner Stern, How I wonder what you are!", 
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 49,
        "text": "I have a meeting at 3pm, kannst du mir sagen wo der Zoom link ist?",
       "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"

    }, 

    {
        "id": 50,
        "text": "Ich hab keinen Hunger, I already ate",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    },

    {
        "id": 51,
        "text": "I need to stop by the bank, kannst du mir sagen wo die nächste Filiale ist?",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    }, 

    {
        "id": 52,
        "text": "I have to go to the doctor, ich fühle mich nicht so gut",
        "pair": "english-german",
        "languages": ["english", "german"],
        "created_by": "Sooriyaa"
    }



]

# %%
df = pd.DataFrame(dataset)
df.to_csv("data/codeswitching_dataset.csv", index=False)

# Printing some basic stats
print(' Number of sentences per language pair: \n ', df['pair'].value_counts())         
print('\nAverage sentence length:\n', df.groupby('pair')['text'].apply(
    lambda x: x.str.split().str.len().mean()  
))
# Out:
#  Number of sentences per language pair:
#   pair
# english-hindi     13
# english-dutch     13
# english-tamil     13
# english-german    13
# Name: count, dtype: int64
#
# Average sentence length:
#  pair
# english-dutch     12.000000
# english-german    14.384615
# english-hindi     12.230769
# english-tamil     13.769231
# Name: text, dtype: float64
