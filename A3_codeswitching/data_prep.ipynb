# %%
import pandas as pd

# %%
# example of data

    {
        "id": ,
        "text": "",
        "pair": "english-",
        "languages": ["english", ""],
        "created_by": "" 
    },

# %%
dataset = [
    {
        "id": 1,
        "text": "yaar I literally samajh nahi aaya kuch bhi in that lecture",
        "pair": "english-urdu",
        "languages": ["english", "urdu"],
        "created_by": "Amina" 
    },

    {
        "id": 2,
        "text": "ik snap het gewoon niet man, deze assignment maakt absoluut geen sense",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 3,
        "text": "het is echt te veel werk, I don't think we'll finish this op tijd",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 4,
        "text": "gezellig was het gisteren, we should definitely do this nog een keertje",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 5,
        "text": "ik heb no clue what we should eat, zullen we gewoon iets orderen",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 6,
        "text": "man het weer is so depressing, ik wil niet naar buiten",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 7,
        "text": "ik ben zo exhausted, I stayed up tot like drie uur vannacht",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 8,
        "text": "calm down joh, je maakt het veel te complicated",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 9,
        "text": "I'm going to do boodschappen, wat voor ingredients heb je nodig voor dinner?",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 10,
        "text": "ik ben echt stressed voor mijn examen, maar ik moet mijn drivers-license halen.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 10,
        "text": "ik heb al voor meerdere part-time jobs applied, maar ik wordt steeds niet gehired.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 11,
        "text": "De grading van deze assignment vind ik eigenlijk wel unfair.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": 12,
        "text": "Ik koop mijn birthday gifts altijd bij de bookstore.",
        "pair": "english-dutch",
        "languages": ["english", "dutch"],
        "created_by": "Gileesa" 
    },

    {
        "id": ,
        "text": "",
        "pair": "english-",
        "languages": ["english", ""],
        "created_by": "" 
    },


    # ADD MORE HERE !
]
